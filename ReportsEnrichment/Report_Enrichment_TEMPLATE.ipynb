# %% [markdown]
# # Process & Enrich Observables from Reports

# %% [markdown]
# ## Setup

# %%
# %%capture

import json
import csv
import vt
import nest_asyncio
import subprocess
import requests
from msticpy import init_notebook
from msticpy.nbtools.ti_browser import browse_results
import os
import jmespath
from dotenv import load_dotenv

load_dotenv()
nest_asyncio.apply()
init_notebook(namespace=globals());

VT_API = os.getenv('VT_API')
OSINT_LINKS = "./reports/reports_links.txt"
IOCPARSER = "https://api.iocparser.com/url"
PARSED_IOCS_DIR = "./reports/parsed_iocs_tc/"

# %% [markdown]
# ## Parse IOCs online open-source reports

# %%
with open(OSINT_LINKS) as osint_links:
    types_to_parse = []
    for link in osint_links:
        request_data = {
            "url": link
        }

        headers = {
            'Content-Type': 'application/json'
        }
        iocparser_request = requests.post(IOCPARSER, headers=headers, json=request_data)
        parsed_iocs = iocparser_request.json()
        article_title = parsed_iocs['meta']['title']
        
        print("Article: ", article_title)
        print(parsed_iocs['meta']['url'])

        # Save IOCs to CSV
        csv_name = article_title.replace(" ", "_")
        
        with open(PARSED_IOCS_DIR + csv_name + ".csv", 'w') as csvfile:
            fieldnames = ['Type', 'Value', 'Rating', 'Confidence', 'Source', 'Description', 'Tags', 'Adversary', 'Document', 'Email', 'Incident', 'Signature', 'Threat']
            writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
            writer.writeheader()

            for attribute, values in parsed_iocs['data'].items():
                print()
                print(attribute)
                print("----------------------------------------")
                for value in values:
                    print(value)
                    if "FILE_HASH" in attribute:
                        writer.writerow({'Type': "File", 'Value': value})
                    elif attribute.startswith("IPv"):
                        writer.writerow({'Type': "Address", 'Value': value})
                    elif attribute == "EMAIL":
                        writer.writerow({'Type': "EmailAddress", 'Value': value})
                    elif attribute == "URL":
                        writer.writerow({'Type': "Url", 'Value': value})
                    elif attribute == "DOMAIN":
                        writer.writerow({'Type': "Host", 'Value': value})
# Out:
# Article:  Hunter Becomes Hunted: Zebra2104 Hides a Herd of Malware
# https://blogs.blackberry.com/en/2021/11/zebra2104
#
# FILE_HASH_SHA1
# ----------------------------------------
#
# DOMAIN
# ----------------------------------------
# trashborting.com
# kavamennci.us
# bertolinnj.us
# eixirienhj.us
# infuuslx.us
# protonmail.com
# mail.premiumclube.org.br
# auswalzenna.us
# megafonasgc.us
# magesty.in-expedition.com
# mentiononecommon.com
# trashborting.com
# ns1.entrydns.net
# ns3.entrydns.net
# ns4.entrydns.net
# mipancepezc.us
# supercombinating.com
# ticket-one-two.com
# ns2.entrydns.net
# any.run
# ticket-one-two.com
# lionarivv.us
# whois.namecheap.com
# zensingergy.us
# booking-sales.com
# xperi.link
# publicdomainregistry.com
# okergeeliw.us
#
# IPv6
# ----------------------------------------
#
# YARA_RULE
# ----------------------------------------
#
# IPv4
# ----------------------------------------
# 87.120.37.120
# 91.92.109.174
#
# EMAIL
# ----------------------------------------
#
# FILE_NAME
# ----------------------------------------
# SecurityHost.exe
# zpsxxla.php
# zxlbw.php
# yymclv.php
# app.php
# Installer.exe
#
# URL
# ----------------------------------------
#
# MAC_ADDRESS
# ----------------------------------------
#
# FILE_HASH_MD5
# ----------------------------------------
#
# CVE
# ----------------------------------------
#
# FILE_HASH_SHA256
# ----------------------------------------
# c936e01333e3260547a8c319d9cfc1811ba5793e182d0688db679ec2b30644c5
# 8844d234d9e18e29f01ff8f64db70274c02953276a2cd1a1a05d07e7e1feb55c
# e843af007ac3f58e26d5427e537cdbddf33d118c79dfed831eee1ffcce474569
#
# ASN
# ----------------------------------------
# AS34224
#
# MITRE_ATT&CK
# ----------------------------------------

# %% [markdown]
# ## Query IOCs within OSINT datasets

# %%
ti_lookup = TILookup(providers=["OTX", "VirusTotal"])

iocs_msticpy = []

for report_csv in os.listdir(PARSED_IOCS_DIR):
    if(report_csv.endswith('.csv')):
        with open(PARSED_IOCS_DIR + report_csv) as csvfile:
            reader = csv.DictReader(csvfile)
            for row in reader:
                iocs_msticpy.append(row['Value'])

results = ti_lookup.lookup_iocs(data=iocs_msticpy, providers=["OTX", "VirusTotal"])

# %% [markdown]
# ## Tabular View of Results

# %%
results_columns_filtered = results[["Ioc", "Provider", "Details", "Severity"]]
results_columns_filtered.sort_values("Ioc")
# Out:
#                                                                  Ioc  \
# 20                                                     87.120.37.120
# 20                                                     87.120.37.120
# 23  8844d234d9e18e29f01ff8f64db70274c02953276a2cd1a1a05d07e7e1feb55c
# 23  8844d234d9e18e29f01ff8f64db70274c02953276a2cd1a1a05d07e7e1feb55c
# 21                                                     91.92.109.174
# 21                                                     91.92.109.174
# 6                                                     auswalzenna.us
# 6                                                     auswalzenna.us
# 2                                                      bertolinnj.us
# 2                                                      bertolinnj.us
# 17                                                 booking-sales.com
# 17                                                 booking-sales.com
# 22  c936e01333e3260547a8c319d9cfc1811ba5793e182d0688db679ec2b30644c5
# 22  c936e01333e3260547a8c319d9cfc1811ba5793e182d0688db679ec2b30644c5
# 24  e843af007ac3f58e26d5427e537cdbddf33d118c79dfed831eee1ffcce474569
# 24  e843af007ac3f58e26d5427e537cdbddf33d118c79dfed831eee1ffcce474569
# 3                                                      eixirienhj.us
# 3                                                      eixirienhj.us
# 4                                                        infuuslx.us
# 4                                                        infuuslx.us
# 1                                                      kavamennci.us
# 1                                                      kavamennci.us
# 15                                                      lionarivv.us
# 15                                                      lionarivv.us
# 8                                          magesty.in-expedition.com
# 8                                          magesty.in-expedition.com
# 5                                           mail.premiumclube.org.br
# 5                                           mail.premiumclube.org.br
# 7                                                     megafonasgc.us
# 7                                                     megafonasgc.us
# 9                                               mentiononecommon.com
# 9                                               mentiononecommon.com
# 11                                                    mipancepezc.us
# 11                                                    mipancepezc.us
# 19                                                     okergeeliw.us
# 19                                                     okergeeliw.us
# 12                                              supercombinating.com
# 12                                              supercombinating.com
# 13                                                ticket-one-two.com
# 14                                                ticket-one-two.com
# 13                                                ticket-one-two.com
# 14                                                ticket-one-two.com
# 0                                                   trashborting.com
# 10                                                  trashborting.com
# 0                                                   trashborting.com
# 10                                                  trashborting.com
# 18                                                        xperi.link
# 18                                                        xperi.link
# 16                                                    zensingergy.us
# 16                                                    zensingergy.us
#
#       Provider  \
# 20  VirusTotal
# 20         OTX
# 23  VirusTotal
# 23         OTX
# 21  VirusTotal
# 21         OTX
# 6          OTX
# 6   VirusTotal
# 2          OTX
# 2   VirusTotal
# 17  VirusTotal
# 17         OTX
# 22  VirusTotal
# 22         OTX
# 24         OTX
# 24  VirusTotal
# 3   VirusTotal
# 3          OTX
# 4   VirusTotal
# 4          OTX
# 1          OTX
# 1   VirusTotal
# 15         OTX
# 15  VirusTotal
# 8   VirusTotal
# 8          OTX
# 5   VirusTotal
# 5          OTX
# 7          OTX
# 7   VirusTotal
# 9   VirusTotal
# 9          OTX
# 11         OTX
# 11  VirusTotal
# 19         OTX
# 19  VirusTotal
# 12         OTX
# 12  VirusTotal
# 13         OTX
# 14         OTX
# 13  VirusTotal
# 14  VirusTotal
# 0          OTX
# 10  VirusTotal
# 0   VirusTotal
# 10         OTX
# 18  VirusTotal
# 18         OTX
# 16  VirusTotal
# 16         OTX
#
#                                                                                                 Details  \
# 20  {'verbose_msg': 'IP address in dataset', 'response_code': 1, 'positives': 2, 'detected_urls': ['...
# 20  {'pulse_count': 34, 'names': ['Malware Command and Control IPs', 'StrongPity, Zebra2104, Phobos,...
# 23  {'verbose_msg': 'Scan finished, information embedded', 'response_code': 1, 'positives': 59, 'res...
# 23  {'pulse_count': 2, 'names': ['StrongPity, Zebra2104, Phobos, MountLocker IoCs', 'Hunter Becomes ...
# 21  {'verbose_msg': 'IP address in dataset', 'response_code': 1, 'positives': 1, 'detected_urls': ['...
# 21  {'pulse_count': 1, 'names': ['Hunter Becomes Hunted: Zebra2104 Hides a Herd of Malware'], 'tags'...
# 6   {'pulse_count': 7, 'names': ['Email Malspam Campaign Infrastructure Analysis', 'StrongPity, Zebr...
# 6   {'verbose_msg': 'Domain found in dataset', 'response_code': 1, 'positives': 0, 'detected_urls': ...
# 2   {'pulse_count': 7, 'names': ['Email Malspam Campaign Infrastructure Analysis', 'StrongPity, Zebr...
# 2   {'verbose_msg': 'Domain found in dataset', 'response_code': 1, 'positives': 3, 'detected_urls': ...
# 17  {'verbose_msg': 'Domain found in dataset', 'response_code': 1, 'positives': 0, 'detected_urls': ...
# 17  {'pulse_count': 12, 'names': ['StrongPity, Zebra2104, Phobos, MountLocker IoCs', 'Hunter Becomes...
# 22  {'verbose_msg': 'Scan finished, information embedded', 'response_code': 1, 'positives': 47, 'res...
# 22  {'pulse_count': 5, 'names': ['PROMETHIUM extends global reach with StrongPity3 APT', 'StrongPity...
# 24  {'pulse_count': 7, 'names': ['PROMETHIUM extends global reach with StrongPity3 APT', 'StrongPity...
# 24  {'verbose_msg': 'Scan finished, information embedded', 'response_code': 1, 'positives': 56, 'res...
# 3   {'verbose_msg': 'Domain found in dataset', 'response_code': 1, 'positives': 0, 'detected_urls': ...
# 3   {'pulse_count': 7, 'names': ['Email Malspam Campaign Infrastructure Analysis', 'StrongPity, Zebr...
# 4   {'verbose_msg': 'Domain found in dataset', 'response_code': 1, 'positives': 0, 'detected_urls': ...
# 4   {'pulse_count': 6, 'names': ['Email Malspam Campaign Infrastructure Analysis', 'StrongPity, Zebr...
# 1   {'pulse_count': 6, 'names': ['Email Malspam Campaign Infrastructure Analysis', 'StrongPity, Zebr...
# 1   {'verbose_msg': 'Domain found in dataset', 'response_code': 1, 'positives': 0, 'detected_urls': ...
# 15  {'pulse_count': 6, 'names': ['Email Malspam Campaign Infrastructure Analysis', 'StrongPity, Zebr...
# 15  {'verbose_msg': 'Domain found in dataset', 'response_code': 1, 'positives': 0, 'detected_urls': ...
# 8   {'verbose_msg': 'Domain found in dataset', 'response_code': 1, 'positives': 11, 'detected_urls':...
# 8   {'pulse_count': 0, 'sections_available': ['general', 'geo', 'url_list', 'passive_dns', 'malware'...
# 5   {'verbose_msg': 'Domain found in dataset', 'response_code': 1, 'positives': 1, 'detected_urls': ...
# 5   {'pulse_count': 0, 'sections_available': ['general', 'geo', 'url_list', 'passive_dns', 'malware'...
# 7   {'pulse_count': 6, 'names': ['Email Malspam Campaign Infrastructure Analysis', 'StrongPity, Zebr...
# 7   {'verbose_msg': 'Domain found in dataset', 'response_code': 1, 'positives': 0, 'detected_urls': ...
# 9   {'verbose_msg': 'Domain found in dataset', 'response_code': 1, 'positives': 4, 'detected_urls': ...
# 9   {'pulse_count': 7, 'names': ['PROMETHIUM extends global reach with StrongPity3 APT', 'StrongPity...
# 11  {'pulse_count': 5, 'names': ['Email Malspam Campaign Infrastructure Analysis', 'StrongPity, Zebr...
# 11  {'verbose_msg': 'Domain found in dataset', 'response_code': 1, 'positives': 0, 'detected_urls': ...
# 19  {'pulse_count': 5, 'names': ['Email Malspam Campaign Infrastructure Analysis', 'Hunter Becomes H...
# 19  {'verbose_msg': 'Domain found in dataset', 'response_code': 1, 'positives': 0, 'detected_urls': ...
# 12  {'pulse_count': 5, 'names': ['What is Astro Locker Team?', 'Hunter Becomes Hunted: Zebra2104 Hid...
# 12  {'verbose_msg': 'Domain found in dataset', 'response_code': 1, 'positives': 4, 'detected_urls': ...
# 13  {'pulse_count': 5, 'names': ['StrongPity, Zebra2104, Phobos, MountLocker IoCs', 'Hunter Becomes ...
# 14  {'pulse_count': 5, 'names': ['StrongPity, Zebra2104, Phobos, MountLocker IoCs', 'Hunter Becomes ...
# 13  {'verbose_msg': 'Domain found in dataset', 'response_code': 1, 'positives': 0, 'detected_urls': ...
# 14  {'verbose_msg': 'Domain found in dataset', 'response_code': 1, 'positives': 0, 'detected_urls': ...
# 0   {'pulse_count': 6, 'names': ['StrongPity, Zebra2104, Phobos, MountLocker IoCs', 'Hunter Becomes ...
# 10  {'verbose_msg': 'Domain found in dataset', 'response_code': 1, 'positives': 9, 'detected_urls': ...
# 0   {'verbose_msg': 'Domain found in dataset', 'response_code': 1, 'positives': 9, 'detected_urls': ...
# 10  {'pulse_count': 6, 'names': ['StrongPity, Zebra2104, Phobos, MountLocker IoCs', 'Hunter Becomes ...
# 18  {'verbose_msg': 'Domain found in dataset', 'response_code': 1, 'positives': 0, 'detected_urls': []}
# 18  {'pulse_count': 1, 'names': ['Hunter Becomes Hunted: Zebra2104 Hides a Herd of Malware'], 'tags'...
# 16  {'verbose_msg': 'Domain found in dataset', 'response_code': 1, 'positives': 0, 'detected_urls': ...
# 16  {'pulse_count': 7, 'names': ['Email Malspam Campaign Infrastructure Analysis', 'StrongPity, Zebr...
#
#        Severity
# 20         high
# 20         high
# 23         high
# 23         high
# 21      warning
# 21      warning
# 6          high
# 6   information
# 2          high
# 2          high
# 17  information
# 17         high
# 22         high
# 22         high
# 24         high
# 24         high
# 3   information
# 3          high
# 4   information
# 4          high
# 1          high
# 1   information
# 15         high
# 15  information
# 8          high
# 8   information
# 5       warning
# 5   information
# 7          high
# 7   information
# 9          high
# 9          high
# 11         high
# 11  information
# 19         high
# 19  information
# 12         high
# 12         high
# 13         high
# 14         high
# 13  information
# 14  information
# 0          high
# 10         high
# 0          high
# 10         high
# 18  information
# 18      warning
# 16  information
# 16         high

# %% [markdown]
# ## Generate IOC Selector Panel

# %%
ti_selector = browse_results(data=results, height="300px", width="800px")
ti_selector
# Out:
# VBox(children=(Text(value='', description='Filter:', style=DescriptionStyle(description_width='initial')), Sel…
# <hr>
# <h2 style='border: 1px solid;background-color: DarkGray; padding: 6px'>e843af007ac3f58e26d5427e537cdbddf33d118c79dfed831eee1ffcce474569</h2><h3 style='background-color: SteelBlue; padding: 6px'>Type: 'sha256_hash', Provider: OTX, severity: high</h3><h4>Details</h4>
# <style>
#     .tb_ti_res {border-collapse: collapse; width: 60%; border: 1px solid #ddd !important;}
#     .cell_ti {border: 1px solid #ddd !important;
#         text-align: left !important; padding: 5px !important; height: 12px}
#     .cell_ti_first {border: 1px solid #ddd !important; width: 25%;
#         text-align: left !important; padding: 5px !important; height: 12px}
# </style>
# <table class='tb_ti_res'><tr class='cell_ti'><td class='cell_ti_first'>OTX</td><tr class='cell_ti'><td class='cell_ti_first'>pulse_count</td><td class='cell_ti'>7</td></tr><tr class='cell_ti'><td class='cell_ti_first'>names</td><td class='cell_ti'>['PROMETHIUM extends global reach with StrongPity3 APT', 'StrongPity APT March-May Campaign', 'StrongPity, Zebra2104, Phobos, MountLocker IoCs', 'Hunter Becomes Hunted: Zebra2104 Hides a Herd of Malware', 'apple.com.stocks_M', 'NPCI Threatfeeds 103 14-10-2020', 'PROMETHIUM extends global reach with StrongPity3 APT']</td></tr><tr class='cell_ti'><td class='cell_ti_first'>tags</td><td class='cell_ti'>[['Backdoor', 'StrongPity', 'APT', 'StrongPity3'], ['strongpity', 'APT', 'backdoor'], ['domain ip', 'country asn', 'asn number', 'ltd as34224', 'domain', 'whois'], ['cobalt strike', 'mountlocker', 'phobos', 'dridex', 'strongpity', 'astrolocker', 'mysterious fourth', 'maze', 'zebra2104', 'iabs', 'april', 'beacons', 'access broker', 'finding beacons', 'dark', 'august'], ['Happy Locker Ransomware', 'Ronjohnson.com'], [], ['Backdoor', 'StrongPity', 'APT', 'StrongPity3']]</td></tr><tr class='cell_ti'><td class='cell_ti_first'>references</td><td class='cell_ti'>[['https://blog.talosintelligence.com/2020/06/promethium-extends-with-strongpity3.html'], ['AT&T Alien Labs', 'https://cybersecurity.att.com/blogs/labs-research/newly-identified-strongpity-operations'], ['https://blogs.blackberry.com/en/2021/11/zebra2104'], ['https://blogs.blackberry.com/en/2021/11/zebra2104'], ['apple.com.stocks_M.pdf'], [], ['https://blog.talosintelligence.com/2020/06/promethium-extends-with-strongpity3.html']]</td></tr></tr></table><h4>Reference: </h4><a href='https://otx.alienvault.com/api/v1/indicators/file/e843af007ac3f58e26d5427e537cdbddf33d118c79dfed831eee1ffcce474569/general'>https://otx.alienvault.com/api/v1/indicators/file/e843af007ac3f58e26d5427e537cdbddf33d118c79dfed831eee1ffcce474569/general</a><br><hr><h4>Raw Results</h4>
#         <details>
#         <summary> <u>Raw results from provider...</u></summary>
#         <pre  style="font-size:11px">{'base_indicator':&nbsp;{'access_reason':&nbsp;'',<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;'access_type':&nbsp;'public',<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;'content':&nbsp;'',<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;'description':&nbsp;'',<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;'id':&nbsp;2231751640,<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;'indicator':&nbsp;'d7aae4694291a7811c18ccc0af9d4b53',<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;'title':&nbsp;'',<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;'type':&nbsp;'FileHash-MD5'},<br>&nbsp;'false_positive':&nbsp;[],<br>&nbsp;'indicator':&nbsp;'e843af007ac3f58e26d5427e537cdbddf33d118c79dfed831eee1ffcce474569',<br>&nbsp;'pulse_info':&nbsp;{'count':&nbsp;7,<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;'pulses':&nbsp;[{'TLP':&nbsp;'white',<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;'adversary':&nbsp;'StrongPity',<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;'attack_ids':&nbsp;[],<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;'author':&nbsp;{'avatar_url':&nbsp;'/otxapi/users/avatar_image/media/avatars/user_2/resized/80/avatar_dacfad0ca8.png',<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;'id':&nbsp;'2',<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;'is_following':&nbsp;True,<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;'is_subscribed':&nbsp;True,<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;'username':&nbsp;'AlienVault'},<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;'cloned_from':&nbsp;None,<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;'comment_count':&nbsp;0,<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;'created':&nbsp;'2020-06-29T16:40:38.272000',<br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;'description':&nbsp ...

# %% [markdown]
# ## [VirusTotal] Get Triggered Yara and IDS Rules

# %%
import vt

vt_client = vt.Client(VT_API)
vt_file_db = []
for report_csv in os.listdir(PARSED_IOCS_DIR):
    if report_csv.endswith('.csv'):
        with open(PARSED_IOCS_DIR + report_csv) as csvfile:
            reader = csv.DictReader(csvfile)
            for row in reader:
                if(row['Type'] == "File"):
                    file_hash = row['Value']
                    try:
                        vt_file = vt_client.get_object("/files/" + file_hash)
                        vt_file_db.append(vt_file)
                    except:
                        pass
vt_client.close()

# %%
for vt_file in vt_file_db:
    yara_list = jmespath.search('crowdsourced_yara_results[*].rule_name', vt_file)
    ids_list = jmespath.search('crowdsourced_ids_results[*].rule_msg', vt_file)
    if (yara_list is not None or ids_list is not None):
        print("\n=============================\nRules for " + file_hash + "\n=============================")                    
        if(yara_list is not None and len(yara_list) > 0):
            print("Yara:")
            print(yara_list)
            print()
        if(ids_list is not None and len(ids_list) > 0):
            print('IDS:')
            print(ids_list)
    if "popular_threat_classification" in vt_file.to_dict():
        print("\nThreat Classification:", vt_file.popular_threat_classification['suggested_threat_label'])
